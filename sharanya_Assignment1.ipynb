# %%
#reading dataset
import pandas as pd
df=pd.read_excel(r"D:/ict/iris.xls")

# %%
#print the columns


#for column names 
print(df.columns)

# to print the entire data frame
print(df)
# Out:
# Index(['SL', 'SW', 'PL', 'PW', 'Classification'], dtype='object')
#       SL   SW   PL   PW  Classification
# 0    5.1  3.5  1.4  0.2     Iris-setosa
# 1    4.9  3.0  1.4  0.2     Iris-setosa
# 2    4.7  3.2  1.3  0.2     Iris-setosa
# 3    4.6  3.1  1.5  0.2     Iris-setosa
# 4    5.0  3.6  1.4  0.2     Iris-setosa
# ..   ...  ...  ...  ...             ...
# 145  6.7  3.0  5.2  2.3  Iris-virginica
# 146  6.3  2.5  5.0  1.9  Iris-virginica
# 147  6.5  3.0  5.2  2.0  Iris-virginica
# 148  6.2  3.4  5.4  2.3  Iris-virginica
# 149  5.9  3.0  5.1  1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
#print the mean
print(df.mean())
# Out:
# SL    5.843333
# SW    3.054000
# PL    3.758667
# PW    1.198667
# dtype: float64

# %%
#to check if any null values present
print(df.isnull().sum())
# Out:
# SL                0
# SW                0
# PL                0
# PW                0
# Classification    0
# dtype: int64

# %% [raw]
# #visualization

# %%
import seaborn as sns
sns.heatmap(df.corr()) # correlation between the variables
# Out:
# <AxesSubplot:>

# %%
# barplot to show the number of items in each class
df['Classification'].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
#frequency of dfferent values in the attributes
df['SL'].plot(kind='hist',color='gray')
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
df['SW'].plot(kind='hist',color='green')
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
df['PL'].plot(kind='hist',color='red')
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
df['PW'].plot(kind='hist',color='blue')
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
#distribution of the data

sns.distplot(df['SL'],color="gray",hist=False,label="SL")
# Out:
# D:\anaconda\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='SL', ylabel='Density'>

# %%
sns.distplot(df['SW'],color="green",hist=False,label="SW")
# Out:
# D:\anaconda\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='SW', ylabel='Density'>

# %%
sns.distplot(df['PL'],color="red",hist=False,label="PL")
# Out:
# D:\anaconda\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='PL', ylabel='Density'>

# %%
sns.distplot(df['PW'],color="blue",hist=False,label="P")
# Out:
# D:\anaconda\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='PW', ylabel='Density'>

# %%
# scatter plot to show the elation between various attributes
import matplotlib.pyplot as plt
plt.scatter(df['SL'],df['PL'])
plt.xlabel('SL')
plt.ylabel('PL')
plt.title('SL vs PL ')
plt.show()
plt.close()


plt.scatter(df['SL'],df['SW'])
plt.xlabel('SL')
plt.ylabel('SW')
plt.title('SL vs SW ')
plt.show()
plt.close()


plt.scatter(df['SL'],df['PW'])
plt.xlabel('SL')
plt.ylabel('PW')
plt.title('SL vs PW ')
plt.show()
plt.close()


plt.scatter(df['PL'],df['PW'])
plt.xlabel('PL')
plt.ylabel('PW')
plt.title('PL vs PW ')
plt.show()
plt.close()


plt.scatter(df['PL'],df['SW'])
plt.xlabel('PL')
plt.ylabel('SW')
plt.title('PL vs SW ')
plt.show()
plt.close()
